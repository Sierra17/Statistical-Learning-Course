# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import seaborn as sns
import sklearn
import missingno as msno

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %% [markdown]
# # Task 2 Ensemble Classifiers - RAW DATA

# %% [markdown]
# ## Reading data

# %% [markdown]
# ### df1

# %%
df1 = pd.read_csv("cancerDat.csv", sep = ";", decimal = ",")

df1 = df1.T # Transpose for n x p (samples x predictor variables)
df1.columns = df1.iloc[0] # Setting the columns the first row
df1 = df1.drop('Unnamed: 0', axis=0) # Dropping the first row
df1
# Out:
# Unnamed: 0 RPAB3_ADQFEYVMYGK LSM8_AEPLNSVAH BUD23_AGFSGGMVVDYPNSAK  \
# NO.REC_1           21.923472      24.442617              19.050562
# NO.REC_2           21.020165      23.649841              18.402413
# NO.REC_3           19.585788      23.736128              18.191527
# NO.REC_4           19.061767      23.374865              17.692775
# NO.REC_5           18.547029      23.039588              19.066973
# ...                      ...            ...                    ...
# REC_51              16.95971      22.084977              15.468719
# REC_52             20.491818      23.722485              18.685077
# REC_53              17.61286      23.882094              17.311329
# REC_54              18.46506      22.328979              18.957264
# REC_55             18.923023      22.964711              17.440432
#
# Unnamed: 0 TLN1_ALEATTEHIR MOES_ALTSELANAR DDX1_APDGYIVK ENAH_ASSTSTPEPTR  \
# NO.REC_1         18.482667       24.086793      20.32946        19.304363
# NO.REC_2         19.088996       24.710323     21.495392        19.454826
# NO.REC_3          16.33124       21.917326     20.284533        16.853825
# NO.REC_4          15.36272       21.484924     18.379603        16.513507
# NO.REC_5         15.835721       21.339587     19.550809        16.831653
# ...                    ...             ...           ...              ...
# REC_51                 NaN       20.465303     18.560795        17.024518
# REC_52                 NaN       22.461809     18.990078         19.90905
# REC_53           16.402293       20.451178     17.990707        14.701493
# REC_54           16.027563       21.679787     18.924127        17.280241
# REC_55           15.913592       21.809651       19.1961        17.541344
#
# Unnamed: 0 NUCKS_ATVTPSPVK STK4_AVGDEMGTVR PSMD3_AVQGFFTSNNATR  ...  \
# NO.REC_1         24.270429       18.878984           18.752264  ...
# NO.REC_2         25.807051       19.091796           19.213397  ...
# NO.REC_3         22.661125       18.215654           20.821777  ...
# NO.REC_4         21.401436        18.38696           19.847221  ...
# NO.REC_5         21.776832        17.85408           20.368534  ...
# ...                    ...             ...                 ...  ...
# REC_51           19.902187       36.306672           17.254904  ...
# REC_52           22.973444       17.793059           20.043865  ...
# REC_53           21.157169       17.338684           18.301701  ...
# REC_54            20.58904       19.948565           19.806399  ...
# REC_55           23.304939       18.130099           19.963527  ...
#
# Unnamed: 0 TLN1_VLVQNAAGSQEK LORF1_VSAMEDEMNEMK LYAG_VTSEGAGLQLQK  \
# NO.REC_1           19.439382          16.142102         22.858297
# NO.REC_2           20.631064                NaN         22.028998
# NO.REC_3           19.123832          16.171227         23.143305
# NO.REC_4           17.958307                NaN         19.183961
# NO.REC_5           18.212854                NaN         22.228449
# ...                      ...                ...               ...
# REC_51             15.771337          16.480685          18.80274
# REC_52              19.56898                NaN         20.911123
# REC_53             16.167853                NaN         20.779238
# REC_54             18.585722          16.531252         21.205814
# REC_55             18.371042                NaN         22.704374
#
# Unnamed: 0 LYAG_WGYSSTAITR SRSF2_YGGGGYGR BAG5_YLDLEEEADTTK CLIC4_YLTNAYSR  \
# NO.REC_1         22.262118      18.079186         17.151515      20.912124
# NO.REC_2         22.031468      17.101384         18.315637      21.512601
# NO.REC_3         22.334392      17.159968         16.859732      19.076147
# NO.REC_4         17.851328      16.564709         15.161135      18.190653
# NO.REC_5         21.385404      17.072001         15.071656      18.896095
# ...                    ...            ...               ...            ...
# REC_51           18.579435      15.941643         16.176746      18.153191
# REC_52           20.261357      17.523338          17.23828      19.652781
# REC_53           20.595174      16.686317         17.416759      17.149354
# REC_54           20.747455       16.61776         16.980207      18.718031
# REC_55           21.750945      16.990441         15.771337      18.977204
#
# Unnamed: 0 NOP16_YMVENHGEDYK SAHH2_YSFMATVTK CAH1_YSSLAEAASK
# NO.REC_1           17.298159       19.097263        21.21211
# NO.REC_2           17.100711       18.875548       23.980238
# NO.REC_3           15.417028       16.340283       19.810886
# NO.REC_4           15.269443       15.411408       18.351433
# NO.REC_5           15.147357             NaN        20.28779
# ...                      ...             ...             ...
# REC_51                   NaN        16.89869       15.644922
# REC_52             16.627121             NaN       20.600316
# REC_53                   NaN       17.842465       18.067661
# REC_54             14.737814       18.155532       18.385178
# REC_55             14.972037       17.589336       19.997471
#
# [129 rows x 102 columns]

# %%
indices1 = np.array(df1.index).astype(str)
index_array1 = np.zeros(len(indices1))
labels_1 = np.where(np.char.startswith(indices1, 'NO.REC_'), 0, np.where(np.char.startswith(indices1, 'REC_'), 1, index_array1))

# %% [markdown]
# ### df2

# %%
df2 = pd.read_csv("cancerInfo.csv", sep = ";")

df2 = df2.drop(['Unnamed: 0'], axis = 1)
df2 = df2.drop(['Group'], axis = 1)
df2.index = df2.iloc[:,0]
df2 = df2.drop(['sampleNames'], axis = 1)
df2
# Out:
#             sites
# sampleNames
# NO.REC_1        A
# NO.REC_2        B
# NO.REC_3        C
# NO.REC_4        C
# NO.REC_5        C
# ...           ...
# REC_51          C
# REC_52          C
# REC_53          C
# REC_54          C
# REC_55          C
#
# [129 rows x 1 columns]

# %%
indices2 = np.array(df2.index).astype(str)
index_array2 = np.zeros(len(indices2))
labels_2 = np.where(np.char.startswith(indices2, 'NO.REC_'), 0, np.where(np.char.startswith(indices2, 'REC_'), 1, index_array2))

# %%
print("Labels are equal: " + str(np.array_equal(labels_1, labels_2))) # That is we can define a single response variable y for the two files
y = labels_1
# Out:
# Labels are equal: True

# %% [markdown]
# ## Checking for NaN and empties in the dataframe

# %% [markdown]
# ### df1

# %%
print(df1.isnull().values.any()) # True -> There are NaN
print(np.where(df1.applymap(lambda x: x == ''))) # Returns row and column indices of empty values -> None
# Out:
# True
# (array([], dtype=int64), array([], dtype=int64))

# %%
NaN_df1_pos = np.where(pd.isnull(df1)) # Returns row and column indices where the value is NaN

# %% [markdown]
# Visual representation of NaNs in the data

# %%
msno.bar(df1)
plt.show()

# %% [markdown]
# ### df2

# %%
print(df2.isnull().values.any()) # False -> No nulls
print(np.where(df2.applymap(lambda x: x == ''))) # Returns row and column indices of empty values - > No empty
print(np.where(pd.isnull(df2))) # Returns row and column indices where the value is NaN -> Void -> No NaNs
# Out:
# False
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# ## Train - test split

# %%
X1 = pd.DataFrame.to_numpy(df1)
X2 = pd.DataFrame.to_numpy(df2) # Made of strings "A", "B", "C". We need to convert as factor.

# %%
print(X2.shape)
X2_original_shape = X2.shape
X2 = np.reshape(X2, [-1]) # "Matrix to vector"
X2.shape
# Out:
# (129, 1)
# (129,)

# %%
label_encoder = sklearn.preprocessing.LabelEncoder()
X2_factors = label_encoder.fit_transform(X2)

# %%
print(X2_factors.shape)
X2_factors = np.reshape(X2_factors, X2_original_shape)
X2_factors.shape
# Out:
# (129,)
# (129, 1)

# %%
X = np.concatenate((X1, X2_factors), axis=1) # Concatenate predictor variables

# %%
print(X.shape) # 129 observations and 103 features
print(y.shape)
# Out:
# (129, 103)
# (129,)

# %%
np.random.seed(1234)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 1234)

# %% [markdown]
# ## Random forest classifier

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Grid search 1 - need not run, result is:  0.813953488372093 [9, 74]

# %%
aux = 0

for n_estimators in range(2, 21):
    for max_features in range(2, 104):
                        
                        
                clf = sklearn.ensemble.RandomForestClassifier(n_estimators = n_estimators, 
                                                              max_features = max_features, 
                                                              random_state = 1234)                
                clf = clf.fit(X_train, y_train)
                y_pred = clf.predict(X_test)
                test_acc = accuracy_score(y_test, y_pred)
                        
                if test_acc > aux:
                    aux = test_acc
                    combination = [n_estimators, max_features]
                    print(aux)
                    print(combination)
# Out:
# 0.4418604651162791
# [2, 2]
# 0.5348837209302325
# [2, 3]
# 0.6046511627906976
# [2, 7]
# 0.6511627906976745
# [2, 16]
# 0.7209302325581395
# [3, 54]
# 0.7441860465116279
# [4, 65]
# 0.7674418604651163
# [7, 76]
# 0.813953488372093
# [9, 74]

# %% [markdown]
# ### Grid search 2 - need not run, result is: 0.8372093023255814 [10, 74, 5, 0.89]

# %%
aux = 0
for n_estimators in [8, 9, 10]:
    for max_features in [73, 74, 75]:
        for max_depth in range(2, 50):
            for max_samples in np.arange(0.01, 1.01, 0.01):
                        
                # print(n_estimators, max_features, max_depth, max_samples)
                        
                        
                clf = sklearn.ensemble.RandomForestClassifier(n_estimators = n_estimators, 
                                                              max_features = max_features, 
                                                              max_depth = max_depth, 
                                                              random_state = 1234, 
                                                              max_samples = max_samples)
                
                clf = clf.fit(X_train, y_train)
                y_pred = clf.predict(X_test)
                test_acc = accuracy_score(y_test, y_pred)
                        
                if test_acc > aux:
                    aux = test_acc
                    combination = [n_estimators, max_features, max_depth, max_samples]
                    print(aux)
                    print(combination)
# Out:
# 0.5581395348837209
# [8, 73, 2, 0.01]
# 0.5813953488372093
# [8, 73, 2, 0.03]
# 0.6511627906976745
# [8, 73, 2, 0.15000000000000002]
# 0.6744186046511628
# [8, 73, 3, 0.59]
# 0.6976744186046512
# [8, 73, 3, 0.86]
# 0.7209302325581395
# [8, 73, 4, 0.93]
# 0.7441860465116279
# [8, 74, 5, 0.86]
# 0.7674418604651163
# [9, 74, 4, 0.89]
# 0.7906976744186046
# [9, 74, 5, 0.89]
# 0.813953488372093
# [9, 74, 6, 1.0]
# 0.8372093023255814
# [10, 74, 5, 0.89]

# %% [markdown]
# ### Final random forest model

# %%
clf = sklearn.ensemble.RandomForestClassifier(n_estimators = 10, 
                                              max_features = 74, 
                                              max_depth = 5, 
                                              random_state = 1234, 
                                              max_samples = 0.89)
                
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
feature_names = list(df1.columns) + list(df2.columns)
class_names = ["class 0", "class 1"]  # Replace with your actual class names
from sklearn import tree


for i in range(0,10):
    estimator = clf.estimators_[i]  # Get the first decision tree from the forest
    
    # Plot the decision tree
    plt.figure(figsize=(20, 10))
    tree.plot_tree(estimator, filled=True, feature_names=feature_names, class_names=class_names)
    plt.show()

# %% [markdown]
# # There cannot be NaN in the data otherwise the importance does not work

# %%
importances = pd.DataFrame({'Predictor' : feature_names,
              'Importance': clf.feature_importances_})

importances.sort_values('Importance', ascending=False)
# Out:
#                   Predictor  Importance
# 0         RPAB3_ADQFEYVMYGK         NaN
# 1            LSM8_AEPLNSVAH         NaN
# 2    BUD23_AGFSGGMVVDYPNSAK         NaN
# 3           TLN1_ALEATTEHIR         NaN
# 4           MOES_ALTSELANAR         NaN
# ..                      ...         ...
# 98           CLIC4_YLTNAYSR         NaN
# 99        NOP16_YMVENHGEDYK         NaN
# 100         SAHH2_YSFMATVTK         NaN
# 101         CAH1_YSSLAEAASK         NaN
# 102                   sites         NaN
#
# [103 rows x 2 columns]

# %%
confusion_mtx = confusion_matrix(y_test, y_pred) 

disp = ConfusionMatrixDisplay(confusion_matrix= confusion_mtx, display_labels= None)
disp.plot(cmap= plt.cm.Blues)
plt.title("Confusion matrix")
plt.show()

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87        24
#          1.0       1.00      0.63      0.77        19
#
#     accuracy                           0.84        43
#    macro avg       0.89      0.82      0.82        43
# weighted avg       0.87      0.84      0.83        43
